# %%
from google_images_download import google_images_download 
from IPython.display import Image
from imageai.Prediction import ImagePrediction
import warnings

warnings.filterwarnings(action='ignore') 

gender = input("성별 입력 ")
item = input("찾고싶은 아이템 ")
keywords = str(gender + " " + item)
response = google_images_download.googleimagesdownload()

arguments = {"keywords":keywords,"limit":1,"output_directory":'image',"no_download":True, "safe_search":True}
paths = response.download(arguments)
paths
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 성별 입력 duwk
# 찾고싶은 아이템 원피스
#
# Item no.: 1 --> Item name = duwk \uc6d0\ud53c\uc2a4
# Evaluating...
# Starting to Print Image URLS
# Image URL: https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg
# Printed url without downloading
#
# Errors: 0
# {'duwk 원피스': ['https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg']}

# %%
paths
# Out:
# {'duwk 원피스': ['https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg']}

# %%
print(paths)
# Out:
# {'duwk 원피스': ['https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg']}

# %%
list(paths.values())[0]
# Out:
# ['https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg']

# %%
import matplotlib.pyplot as plt

from skimage import io

url ='http://azumall.com/upload/goods/a68303_mia203bkgif.jpg'

img = io.imread(url)

plt.imshow(img)

plt.show()

plt.savefig("1. a68303_mia203bkgif.jpg")

# %%
import matplotlib.pyplot as plt
from skimage import io

url ='https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg'
img = io.imread(url)
plt.imshow(img)
#plt.show()
#plt.pig("파일 이름.확장자")

# %%
from PIL import Image
import requests
from io import BytesIO
url = "https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg"
response = requests.get(url)
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x20D30F78278>

# %%
from google_images_download import google_images_download 
from IPython.display import Image
from imageai.Prediction import ImagePrediction
import warnings

warnings.filterwarnings(action='ignore') 

response = google_images_download.googleimagesdownload()

url ='https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg'
arguments = {"similar_images":url,"limit":1,"output_directory":'image',"no_download":True,"safe_search":True}
paths = response.download(arguments)
paths
# Out:
# Item no.: 1 --> Item name = 2019-05-06 19_37_39
# Evaluating...
# https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg
# Starting to Print Image URLS
# Image URL: https://pbs.twimg.com/media/CrUsD6VVMAAAPAH.jpg
# Printed url without downloading
#
# Errors: 0
# {'2019-05-06 19_37_39': ['https://pbs.twimg.com/media/CrUsD6VVMAAAPAH.jpg']}

# %%
from google_images_download import google_images_download 
from imageai.Prediction import ImagePrediction
from PIL import Image
from io import BytesIO

import requests
import warnings
warnings.filterwarnings(action='ignore') 

gender = input("성별 입력: ")
item = input("찾고싶은 아이템: ")
while True:

    keywords = str(gender + " " + item)
    response = google_images_download.googleimagesdownload()
    arguments = {"keywords":keywords,"limit":1,"output_directory":'image',"no_download":True, "safe_search":True}
    paths = response.download(arguments)
    choice = input("평가를 해주세요 (cool or bad): ")
    if choice == 'cool':
        url_origin = str(list(paths.values())[0])
        url_cut = url_origin[2:]
        url = url_cut[:-2]
        response = requests.get(url)
        img = Image.open(BytesIO(response.content))
        break
    elif choice == 'bad':
        item = item + 'a'
        continue
    else:
        print('올바른 평가를 해주세요')
        break

img
# Out:
# 성별 입력: 남자
# 찾고싶은 아이템: 슈트
#
# Item no.: 1 --> Item name = \ub0a8\uc790 \uc288\ud2b8
# Evaluating...
# Starting to Print Image URLS
# Image URL: http://mblogthumb1.phinf.naver.net/20111226_132/ewtvywmk_1324895333801Idz0d_JPEG/3.jpg?type=w2
# Printed url without downloading
#
# Errors: 0
#
# 평가를 해주세요 (cool or bad): bad
#
# Item no.: 1 --> Item name = \ub0a8\uc790 \uc288\ud2b8a
# Evaluating...
# Starting to Print Image URLS
# Image URL: https://i.pinimg.com/736x/b3/9c/2c/b39c2c33335d1e568c858c0a4274a7ca.jpg
# Printed url without downloading
#
# Errors: 0
#
# 평가를 해주세요 (cool or bad): bad
#
# Item no.: 1 --> Item name = \ub0a8\uc790 \uc288\ud2b8aa
# Evaluating...
# Starting to Print Image URLS
# Image URL: http://image.auction.co.kr/itemimage/14/35/ec/1435ec2666.jpg
# Printed url without downloading
#
# Errors: 0
#
# 평가를 해주세요 (cool or bad): shit
# 올바른 평가를 해주세요
#
# Item no.: 1 --> Item name = \ub0a8\uc790 \uc288\ud2b8aa
# Evaluating...
# Starting to Print Image URLS
# ...
