# %%
import matplotlib.pyplot as plt
from skimage import io

url ='https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg'
img = io.imread(url)
plt.imshow(img)
#plt.show()
#plt.pig("파일 이름.확장자")

# %%
from PIL import Image
import requests
from io import BytesIO
url = "https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg"
response = requests.get(url)
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x20D30F78278>

# %%
from google_images_download import google_images_download 
from imageai.Prediction import ImagePrediction
from PIL import Image
from io import BytesIO


import requests
import warnings
warnings.filterwarnings(action='ignore') 

gender = input("성별 입력: ")
item = input("찾고싶은 아이템: ")
count = 0
while True:
    
    c = str(count)
    keywords = str('20대' + gender + " " + item + c)
    response = google_images_download.googleimagesdownload()
    arguments = {"keywords":keywords,"limit":1,"output_directory":'image',"no_download":True, "safe_search":True}
    paths = response.download(arguments)
    choice = input("평가를 해주세요 (cool or bad): ")
    if choice == 'cool':
        #url_origin = str(list(paths.values())[0])
        #url_cut = url_origin[2:]
        #url = url_cut[:-2]
        url = paths[0][keywords][0]
        resp = requests.get(url)
        img = Image.open(BytesIO(resp.content))
        break
    elif choice == 'bad':
        #item = item + str(count)
        count += 1
        continue
    else:
        print('올바른 평가를 해주세요')
        break

img
# Out:
# 성별 입력: 남자
# 찾고싶은 아이템: 슈트
#
# Item no.: 1 --> Item name = 20\ub300\ub0a8\uc790 \uc288\ud2b80
# Evaluating...
# Getting URLs without downloading images...
# Image URL: http://mblogthumb2.phinf.naver.net/MjAxODAyMDlfMjIx/MDAxNTE4MTAyNzExOTQ4.t5yRaWrC2M2AXzsrATLZEhiDWuP7l97Xzln0X-TKzr0g.CWu4ehcRWAoPH3w7QN5yued1RKPt0bGXw7FFptTqYhAg.JPEG.djkek85/000306.jpg?type=w800
# Printed url without downloading
#
# Errors: 0
#
# 평가를 해주세요 (cool or bad): bad
#
# Item no.: 1 --> Item name = 20\ub300\ub0a8\uc790 \uc288\ud2b81
# Evaluating...
# Getting URLs without downloading images...
# Image URL: https://post-phinf.pstatic.net/MjAxNzA5MDFfMjgy/MDAxNTA0MjU4NjExODY1.6pmt4NgKk4TMqUkGe-bMBLknRjvVlDzEgmAIR83Whbsg.1FqnP9o4LE5i6n9c5Y-ohw0IK_7KUpOzoKjXI23ZaN0g.JPEG/1.jpg?type=w1200
# Printed url without downloading
#
# Errors: 0
#
# 평가를 해주세요 (cool or bad): bad
#
# Item no.: 1 --> Item name = 20\ub300\ub0a8\uc790 \uc288\ud2b82
# Evaluating...
# Getting URLs without downloading images...
# Image URL: http://blogthumb2.naver.net/20160211_80/kdd_house_1455125985231J4Sib_JPEG/KakaoTalk_20160210_004302369%282%29.jpg?type=w2
# Printed url without downloading
#
# Errors: 0
#
# 평가를 해주세요 (cool or bad): cool
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=743x743 at 0x26A8849AF98>

# %%
paths
# Out:
# ({'20대남자 슈트2': ['http://blogthumb2.naver.net/20160211_80/kdd_house_1455125985231J4Sib_JPEG/KakaoTalk_20160210_004302369%282%29.jpg?type=w2']},
#  0)

# %%
paths[0]
# Out:
# {'20대남자 슈트2': ['http://blogthumb2.naver.net/20160211_80/kdd_house_1455125985231J4Sib_JPEG/KakaoTalk_20160210_004302369%282%29.jpg?type=w2']}

# %%
keywords
# Out:
# '20대남자 슈트2'
