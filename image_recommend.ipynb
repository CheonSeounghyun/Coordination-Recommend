# %%
import matplotlib.pyplot as plt
from skimage import io

url ='https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg'
img = io.imread(url)
plt.imshow(img)
#plt.show()
#plt.pig("파일 이름.확장자")

# %%
from PIL import Image
import requests
from io import BytesIO
url = "https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg"
response = requests.get(url)
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x1B11DF9DF98>

# %%
from google_images_download import google_images_download 
from imageai.Prediction import ImagePrediction
from PIL import Image
from io import BytesIO


import requests
import warnings
warnings.filterwarnings(action='ignore') 

gender = input("성별 입력: ")
item = input("찾고싶은 아이템: ")
count = 0
while True:
    
    c = str(count)
    keywords = str('20대 ' + gender + " " + item + c)
    response = google_images_download.googleimagesdownload()
    arguments = {"keywords":keywords,"limit":1,"output_directory":'image',"no_download":True, "safe_search":True}
    paths = response.download(arguments)
    choice = input("평가를 해주세요 (cool or bad): ")
    if choice == 'cool':
        #url_origin = str(list(paths.values())[0])
        #url_cut = url_origin[2:]
        #url = url_cut[:-2]
        url = paths[keywords][0]
        resp = requests.get(url)
        img = Image.open(BytesIO(resp.content))
        break
    elif choice == 'bad':
        #item = item + str(count)
        count += 1
        continue
    else:
        print('올바른 평가를 해주세요')
        break

img
# Out:
# 성별 입력: 여자
# 찾고싶은 아이템: 원피스
#
# Item no.: 1 --> Item name = 20\ub300 \uc5ec\uc790 \uc6d0\ud53c\uc2a40
# Evaluating...
# Starting to Print Image URLS
# Image URL: http://two-code.com/web/product/big/201812/d3a0cb5b25fbf40986c28de520491aec.gif
# Printed url without downloading
#
# Errors: 0
#
# 평가를 해주세요 (cool or bad): bad
#
# Item no.: 1 --> Item name = 20\ub300 \uc5ec\uc790 \uc6d0\ud53c\uc2a41
# Evaluating...
# Starting to Print Image URLS
# Image URL: http://mblogthumb1.phinf.naver.net/MjAxNzA3MjRfMjE2/MDAxNTAwOTA0NDE5NTM0.Fa128qjlR2vSIDi5nZ4lw87pdPBB8496XOeQMoWZcBsg.jjfBpTF6RsI9VH8YhO7iZ_01xOVSGvACUwaOt0xktsAg.JPEG.s2sue/20%EB%8C%80%EC%97%AC%EC%9E%90%EC%87%BC%ED%95%91%EB%AA%B0_%ED%94%8C%EB%9D%BC%EC%9B%8C%EB%A1%B1%EC%9B%90%ED%94%BC%EC%8A%A4_%281%29.jpg?type=w800
# Printed url without downloading
#
# Errors: 0
#
# 평가를 해주세요 (cool or bad): bad
#
# Item no.: 1 --> Item name = 20\ub300 \uc5ec\uc790 \uc6d0\ud53c\uc2a42
# Evaluating...
# Starting to Print Image URLS
# Image URL: https://shop.r10s.jp/partydress-7/cabinet/repo1n/1646.jpg
# Printed url without downloading
#
# Errors: 0
#
# 평가를 해주세요 (cool or bad): cool
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x800 at 0x1B11D32AB00>
