# %%
from google_images_download import google_images_download 
from IPython.display import Image
from imageai.Prediction import ImagePrediction
import warnings

warnings.filterwarnings(action='ignore') 

gender = input("성별 입력 ")
item = input("찾고싶은 아이템 ")
keywords = str(gender + " " + item)
response = google_images_download.googleimagesdownload()

arguments = {"keywords":keywords,"limit":1,"output_directory":'image',"no_download":True, "safe_search":True}
paths = response.download(arguments)
paths
# Out:
# 성별 입력 여자
# 찾고싶은 아이템 원피스
#
# Item no.: 1 --> Item name = \uc5ec\uc790 \uc6d0\ud53c\uc2a4
# Evaluating...
# Starting to Print Image URLS
# Image URL: https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg
# Printed url without downloading
#
# Errors: 0
# {'여자 원피스': ['https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg']}

# %%
paths
# Out:
# {'여자 원피스': ['https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg']}

# %%
print(paths)
# Out:
# {'여자 원피스': ['https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg']}

# %%
list(paths.values())[0]
# Out:
# ['https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg']

# %%
import matplotlib.pyplot as plt

from skimage import io

url ='http://azumall.com/upload/goods/a68303_mia203bkgif.jpg'

img = io.imread(url)

plt.imshow(img)

plt.show()

plt.savefig("1. a68303_mia203bkgif.jpg")

# %%
import matplotlib.pyplot as plt
from skimage import io

url ='https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg'
img = io.imread(url)
plt.imshow(img)
#plt.show()
#plt.pig("파일 이름.확장자")

# %%
from PIL import Image
import requests
from io import BytesIO
url = "https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg"
response = requests.get(url)
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x13D1D8EE240>

# %%
from google_images_download import google_images_download 
from imageai.Prediction import ImagePrediction
from PIL import Image
from io import BytesIO

import requests
import warnings
warnings.filterwarnings(action='ignore') 

gender = input("성별 입력 ")
item = input("찾고싶은 아이템 ")
keywords = str(gender + " " + item)
response = google_images_download.googleimagesdownload()

arguments = {"keywords":keywords,"limit":1,"output_directory":'image',"no_download":True, "safe_search":True}
paths = response.download(arguments)

url_origin = str(list(paths.values())[0])
url_cut = url_origin[2:]
url = url_cut[:-2]
response = requests.get(url)
img = Image.open(BytesIO(response.content))
img
#input("평가를 해주세요")
# Out:
# 성별 입력 여자
# 찾고싶은 아이템 원피스
#
# Item no.: 1 --> Item name = \uc5ec\uc790 \uc6d0\ud53c\uc2a4
# Evaluating...
# Starting to Print Image URLS
# Image URL: https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg
# Printed url without downloading
#
# Errors: 0
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x201D99C7E10>
