# %%
import matplotlib.pyplot as plt
from skimage import io

url ='https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg'
img = io.imread(url)
plt.imshow(img)
#plt.show()
#plt.pig("파일 이름.확장자")

# %%
from PIL import Image
import requests
from io import BytesIO
url = "https://seoul-p-studio.bunjang.net/product/59787605_1_1472785104_w640.jpg"
response = requests.get(url)
img = Image.open(BytesIO(response.content))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640 at 0x20D30F78278>

# %%
from google_images_download import google_images_download 
from imageai.Prediction import ImagePrediction
from PIL import Image
from io import BytesIO


import requests
import warnings
warnings.filterwarnings(action='ignore') 

gender = input("성별 입력: ")
item = input("찾고싶은 아이템: ")
while True:

    keywords = str(gender + " " + item)
    response = google_images_download.googleimagesdownload()
    arguments = {"keywords":keywords,"limit":1,"output_directory":'image',"no_download":True, "safe_search":True}
    paths = response.download(arguments)
    choice = input("평가를 해주세요 (cool or bad): ")
    if choice == 'cool':
        #url_origin = str(list(paths.values())[0])
        #url_cut = url_origin[2:]
        #url = url_cut[:-2]
        url = paths[0][keywords][0]
        resp = requests.get(url)
        img = Image.open(BytesIO(resp.content))
        break
    elif choice == 'bad':
        item = item + 'a'
        continue
    else:
        print('올바른 평가를 해주세요')
        break

img
# Out:
# 성별 입력: 남자
# 찾고싶은 아이템: 슈트
#
# Item no.: 1 --> Item name = \ub0a8\uc790 \uc288\ud2b8
# Evaluating...
# Getting URLs without downloading images...
# Image URL: http://mblogthumb1.phinf.naver.net/20111226_132/ewtvywmk_1324895333801Idz0d_JPEG/3.jpg?type=w2
# Printed url without downloading
#
# Errors: 0
#
# 평가를 해주세요 (cool or bad): bad
#
# Item no.: 1 --> Item name = \ub0a8\uc790 \uc288\ud2b8a
# Evaluating...
# Getting URLs without downloading images...
# Image URL: https://post-phinf.pstatic.net/MjAxNzA3MTNfMTQz/MDAxNDk5OTI4NDYxNjg1.nWCDkwRaC48y6f3BxFzmihcv5S42yM-j9ZidGdJ_qo0g.66QoRyn6MO_77Ji60OZfW9ZW1_RpTrU_fLk4tGGuiOUg.JPEG/5.%EC%BB%A4%EC%8A%A4%ED%85%80%EB%A9%9C%EB%A1%9C%EC%9A%B0_%EC%88%98%ED%8A%B8.jpg?type=w1200
# Printed url without downloading
#
# Errors: 0
#
# 평가를 해주세요 (cool or bad): cool
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x550 at 0x2159691E080>
